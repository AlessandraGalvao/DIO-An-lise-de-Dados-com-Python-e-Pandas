# %%
print ("Olá Mundo")
# Out:
# Olá Mundo

# %%
print ("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
# Apredendo as Operações:

# %%
#Multiplicação
2*5
# Out:
# 10

# %%
#Divisão:
10/2
# Out:
# 5.0

# %%
#Variáveis

# %%
a = 6
b = 2

# %%
a + b
# Out:
# 8

# %%
# Criando Váriáves Tipo String

# %%
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:15]
# Out:
# 'Python para aná'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace("Python", "Frases")
# Out:
# 'Frases para análise de dados'

# %%
frase=frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

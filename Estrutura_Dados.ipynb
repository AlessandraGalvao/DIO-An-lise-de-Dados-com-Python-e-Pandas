# %%
#Criando uma Lista chamada animais

# %%
animais = [1,2,3]

# %%
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gatos", 12345, 6, 5]
animais
# Out:
# ['cachorro', 'gatos', 12345, 6, 5]

# %%
#Imprimpindo o primeiro item da Lista

# %%
animais[0
      ]
# Out:
# 'cachorro'

# %%
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gatos', 12345, 6, 5]

# %%
#Removendo elementos da lista
animais.remove("gatos")

# %%
animais
# Out:
# ['papagaio', 12345, 6, 5]

# %%
len(animais)
# Out:
# 4

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leão")

# %%
animais
# Out:
# ['papagaio', 12345, 6, 5, 'leão']

# %%
animais.extend(["cobra",6])

# %%
animais
# Out:
# ['papagaio', 12345, 6, 5, 'leão', 'cobra', 6]

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %%
#Tuplas
#Tuplas usam parênteses com sintaxe

# %%
tp=("Banana", "Maça", 10, 50)

# %%
#As tupas são imutáveis

# %%
tp.count("Maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maça')

# %%
#Dicionários
#Para criair dicionários usamos as{}

# %%
dc = {"Maçã":10, "Banana": 20, "Uva":2}

# %%
#Conceito de chave e valor

# %%
dc
# Out:
# {'Maçã': 10, 'Banana': 20, 'Uva': 2}

# %%
#Atualizando o valor de Maçã
dc["Maçã"]=25

# %%
dc
# Out:
# {'Maçã': 25, 'Banana': 20, 'Uva': 2, 'Maça': 25}

# %%
#Retornando todas as Chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Uva', 'Maça'])

# %%
#Retornando os Valores do dicionário
dc.values()
# Out:
# dict_values([25, 20, 2, 25])

# %%
#Verificando se já existe chave no diionário e caso não exista insere
dc.setdefault("Limão",22)
# Out:
# 22

# %%
dc
# Out:
# {'Maçã': 25, 'Banana': 20, 'Uva': 2, 'Maça': 25, 'Limão': 22}

# %%
dc
